# %% [markdown]
# # Worksheet 5: Linear Regression
#
# In this worksheet, we will work with a sample dataset to practice with basic linear regression modeling in Python.
#
# ## Horseshoe Crabs Data
#
# The dataset contains measurements on 173 female horseshoe crabs:
#
# - `color`: integer (1–4)
# - `spine`: condition (1=both good, 2=one worn/broken, 3=both worn/broken)
# - `width`: carapace width in cm
# - `satell`: number of satellite males
# - `weight`: weight in grams
#
# The aim is to practice the following:
#
# - Fit linear regression models with categorical predictors
# - Create and interpret indicator variables and interactions
# - Extract model coefficients, diagnostics, and predictions
# - Compare models using R²

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import IsolationForest

import sweetviz as sv

# %% [markdown]
# The following line will read the data into Python. Follow it up with an automated `sweetviz` EDA, with `weight` as the target variable.

# %%
# Load the crab dataset
crab = pd.read_csv('data/crab.txt', sep='\\s+',)

# %%
my_report = sv.analyze(crab, target_feat='weight')
my_report.show_notebook()
# Out:
#                                              |                          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# ## Ex. 1: Inspect the Data
#
# Create a boxplot of `weight`(y-axis) vs `spine` (x-axis). Comment on how crab weights differ across spine conditions.

# %% [markdown]
# ## Ex. 2: Outliers
#
# Use an Isolation Forest to identify the outliers in this dataset, and explain why they are being identified as outliers.

# %% [markdown]
# ## Ex. 3: Fitting all variables
#
# Fit a model with `weight` as the dependent variable, and all other variables as the independent. Consider and decide for yourself whether `color` and `spine` should be
# treated as categorical or numeric.

# %% [markdown]
# ## Ex. 4: Create a plot with three variables
#
# Use `seaborn` to create a plot with `weight` on the y-axis, and two other variables: `color` and `spine`. What do you observe about the relationship?

# %% [markdown]
# ## Ex. 5: Improving the model
#
# Use the information from the plot in Ex. 4 to improve the model's adjusted R-squared value.

# %% [markdown]
# ## Ex. 6: Inspecting residuals
#
# Extract the standardised residuals. Which points have the absolute residuals greater than 3 (in absolute value)? Are these points also outliers, as identified by the Isolation Forest?

# %% [markdown]
# ## Ex. 7: Scatterplot
#
# Create a scatterplot of `weight` versus `width`. Which are the outlier points? And which points are the ones with large residuals?

# %% [markdown]
# ## Ex. 8: Dealing with an influential point
#
# Add an indicator variable for point at `width` = 5.20. Now refit the model to see if there is an improvement in the adjusted R-squared.
