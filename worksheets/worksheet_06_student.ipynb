# %% [markdown]
# # Worksheet 6: Time Series Forecasting
#
# In this worksheet, you'll fit and compare multiple time series models: ARIMA, exponential smoothing (ETS), and seasonal decomposition. We'll evaluate how well each captures trends, seasonality, and forecasting accuracy.
#
# First, we load the required packages.

# %%
import pandas as pd
import numpy as np
from numpy.random import default_rng
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from itables import show

from statsmodels.tsa.stattools import adfuller, acf, pacf, kpss
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose, STL
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.api import ( 
  ExponentialSmoothing, SimpleExpSmoothing, Holt, STLForecast
) 
import pmdarima as pm

from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %% [markdown]
# Our next step is to load the data into Python and ensure all dates are read in correctly.

# %%
tourism_df = pd.read_excel('data/international_visitor_arrivals_sg.xlsx',
                        parse_dates=[0], date_format="%Y %b", na_values='na')
x = pd.to_datetime(tourism_df['Data Series'].str.strip(), format="%Y %b")
tourism_df['Date'] = x
tourism_df = tourism_df.sort_values('Date').reset_index(drop=True)

# %%
tourism_continents_df = tourism_df.iloc[:, [63, 2, 11, 16, 20, 26, 33, 37, 53, 57]].copy()
tourism_continents_df.columns = ['Date', 'SEA', 'greater_china', 'north_asia',
                                 'south_asia', 'west_asia', 'americas',
                                 'europe', 'oceania', 'africa']

# %% [markdown]
# The dataset contains 45 years of monthly tourist arrivals into Singapore. However, some months from some
# continents contain missing data.

# %% [markdown]
# ## Ex. 1: Filter the data
#
# Filter the dataframe to keep only the rows corresponding to 2006-01-01 to 2020-01-01 (inclusive). This way we have 14+ years of data for all series. Create a time series plot of the arrivals from greater China.

# %% [markdown]
# ## Ex. 2: Seasonal decomposition
#
# Create a seasonal decomposition of the SEA data using STL. Defining the trend strength and seasonal strength to be:
#
# Trend strength:
# $$
# F_T = \max\left(0, 1 - \frac{Var(R_t)}{Var(R_t + T_t)}  \right)
# $$
#
# Seasonal strength:
# $$
# F_S = \max\left(0, 1 - \frac{Var(R_t)}{Var(R_t + S_t)}  \right)
# $$
#
# Based on the default STL decomposition, compute $F_T$ and $F_S$ for the greater China series.

# %% [markdown]
# ## Ex. 3: Iterate over all series
#
# Iterate over all 9 series to compute the trend and seasonal strengths. Then recreate the following plot:

# %% [markdown]
# ## Ex 4: Fit an ETS(A, M, A) model
#
# Fit an ETS(AMA) model to any one of the time series

# %% [markdown]
# ## Ex. 5: Inspect the residuals from the ETS model
#
# Extract the residuals from the ETS models and create diagnostic plots for them.

# %% [markdown]
# ## Ex. 6: Auto-ARIMA
#
# Fit an Auto-ARIMA model and inspect the residuals to same series.

# %% [markdown]
# ## Ex. 7: Compare the two models
#
# Compare the two models according to their RMSE on the fitted values. Which is a better fit?
