# %% [markdown]
# # Worksheet 3: Multivariate Exploration of the Happiness Dataset
#
# Use `happiness_report.csv` (introduced in Chapter 1). Unless stated otherwise, work with the **2017** rows only, and use these seven numeric columns as your feature set:
#
# `GDP`, `Family`, `Life.Expectancy`, `Freedom`, `Govt.Corruption`, `Generosity`,
# `Dystopia.Residual`
#
# Run the following cell first, without modification.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from itables import show

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from scipy.stats import f_oneway
from statsmodels.stats.multicomp import pairwise_tukeyhsd

rng = np.random.default_rng(2024)

happ = pd.read_csv('data/happiness_report.csv', header=0, na_values='NA')
country_continent = pd.read_csv('data/country_continent.csv')

feats = ['GDP', 'Family', 'Life.Expectancy', 'Freedom',
         'Govt.Corruption', 'Generosity', 'Dystopia.Residual']

show(happ)

# %% [markdown]
# ## Ex. 1: Scaling the dataset
#
# Preprocess the data with the following steps:
#
# 1. Filter `happ` to `Year == 2017`
# 2. Drop rows with missing values in `feats`
# 3. Reset the index.
#
# Then standardise the seven feature columns with `StandardScaler` and store the result in `X`.

# %% [markdown]
# ## Ex. 2: Extracting principal components
#
# Fit a `PCA()` on `X` and report the proportion of variance explained by the first two components.

# %% [markdown]
# ## Ex. 4: Create a scatter plot of PC1 vs. PC2
#
# Inspect the loadings on the first two principal components and comment on them.

# %% [markdown]
# ## Ex. 5: Run a t-SNE visualisation on the original dataset

# %% [markdown]
# Create an interactive plot to display the t-SNE output, and colour the points by Happiness Score.

# %% [markdown]
# ## Ex. 6: Hierarchical Clustering
#
# Build a ward-linkage hierarchical clustering on `X` using `linkage(X, method='ward')`, and plot the dendrogram with country names as leaf labels.

# %% [markdown]
# ## Ex. 7: Cut the tree into 3 clusters.
#
# Store the result as a new `cluster` column, and report the mean `Happiness.Score` per cluster.
