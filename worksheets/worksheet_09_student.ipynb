# %% [markdown]
# # Worksheet 9: Computer Vision
#
# ## Overview
#
# This worksheet practices core computer vision skills: reading and manipulating image arrays, edge detection, running pretrained models, and extracting/saving results to disk.
#
# All exercises build on the boat image (`data/New_Zealand_Boat.jpg`).

# %%
import cv2
import sys
import numpy as np
import os

import matplotlib.pyplot as plt
from matplotlib import colormaps
from IPython.display import YouTubeVideo, display, HTML, Image, Video

# %% [markdown]
# ## Ex. 1: Read and save images
#
# OpenCV reads images as BGR (not RGB). Manipulation is just array indexing and basic operations. Read in the image file, crop it to contain only the boat, and save it as a few png file.

# %% [markdown]
# ## Ex. 2: Flip the boat
#
# Use numpy operations to flip the *grayscale* version of the boat about its y-axis.

# %% [markdown]
# ## Ex. 3: Use colour masking
#
# Use the same colour masking approach as the lecture to create a binary mask indicating the location of the red sail.

# %% [markdown]
# ## Ex. 4: Canny edge detection
#
# Use Canny edge detection *on the cropped boat image* to extract the edges.

# %% [markdown]
# ## Ex 5: Use Hough Lines to extract the sail

# %% [markdown]
# ## Ex. 6: Object Detection
#
# For this section, download and apply a classsification/detection model on this image. Extract the bounding box corresponding to the object(s) detected.
